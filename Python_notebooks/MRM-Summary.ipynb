# %%
import pandas as pd

# %%
### Extract most important information from MRM Assays

# %%
protein_list = ["P01008","P05109","P05109","P08246","P20160","P24158","P80188","P80511","P06702"]

with pd.ExcelWriter("Supplementary File X.xlsx", engine="openpyxl") as writer:
  for protein in protein_list:
    mrm_assay = pd.read_csv(r"C:\Users\max-w\Desktop\Paper\Manuskripte(Metastudie)\SupplementaryMaterial\SupplementaryFiles\SupplementaryFileX(Revision)-MRM-Assays\MRMAssayDB - Result - "+protein+".csv")
    data = mrm_assay.drop(["STRING_ID","Disease Data","GO_Term_Name","Drug Association","Mean Concentration","Concentration","Pathway Name"], axis="columns")
    #df = pd.DataFrame(data)
    data.to_excel(writer, sheet_name=protein, index=False)

# %%
mrm_assay = pd.read_csv(r"C:\Users\max-w\Desktop\Paper\Manuskripte(Metastudie)\SupplementaryMaterial\SupplementaryFiles\SupplementaryFileX(Revision)-MRM-Assays\MRMAssayDB - Result - P01008.csv")

# %%
mrm_assay.drop(["STRING_ID","Disease Data","GO_Term_Name","Drug Association","Mean Concentration","Concentration","Pathway Name"], axis="columns")
